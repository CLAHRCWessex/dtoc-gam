# %% [markdown]
# # Generalised Additive Model - analysis of relationship between DToCs and ED breaches

# %% [markdown]
# Imports

# %%
require(mgcv)
require(nlme)
require(car)
library(data.table)
library(ggplot2)

# %% [markdown]
# Read in and process data

# %%
#data = read.csv("input/20180913_diff_dtoc.csv")
dtoc = read.csv("input/dtoc.csv")

# %%
dtoc$yr = as.numeric(substr(dtoc$year, 1, 4))

# %%
head(dtoc)
# Out:
#   year    month     total_atten total_atten_t1 total_atten_.4hr X95._targ
# 1 2010-11 August    1719197     1138652        33184.00         0.9806980
# 2 2010-11 September 1715117     1150728        41151.00         0.9760069
# 3 2010-11 October   1753934     1163143        47414.00         0.9729671
# 4 2010-11 November  1604591     1111295        46436.43         0.9710603
# 5 2010-11 December  1647824     1159204        89917.29         0.9454327
# 6 2010-11 January   1654907     1133881        72889.29         0.9559557
#   total_admissions dtoc_a dtoc_na dtoc_total mth time yr
# 1 425702.0         2559   2381    4940        8  1    2010
# 2 424900.0         2647   2357    5004        9  2    2010
# 3 436215.0         2513   2075    4588       10  3    2010
# 4 429099.0         2352   2057    4409       11  4    2010
# 5 452728.7         1995   1866    3861       12  5    2010
# 6 442003.7         2563   2034    4597        1  6    2010

# %% [markdown]
# Preliminary look at time series

# %%
ts_breach = ts(dtoc$total_atten_.4hr)
ts_dtoc = ts(dtoc$dtoc_total)
ts_attend = ts(dtoc$total_atten_t1)
ts_admit = ts(dtoc$total_admissions)

# %%
par(mfrow=c(2,2))
plot.ts(ts_breach,xy.lines=F,xy.labels=F) #  (increasing variance)
plot.ts(ts_dtoc,xy.lines=F,xy.labels=F)
plot.ts(ts_attend,xy.lines=F,xy.labels=F)
plot.ts(ts_admit,xy.lines=F,xy.labels=F)
# Out:
# plot without title

# %% [markdown]
# ## Utility functions

# %%
plot_fit <-function(gam, title){
    datas <- rbindlist(list(data.table(breaches = dtoc$total_atten_.4hr,time= dtoc$time),
    data.table(breaches = gam$fitted.values,time = dtoc$time)))

    datas[, type := c(rep("Real", nrow(dtoc)), rep("Fitted", nrow(dtoc)))]

    ggplot(data = datas, aes(time, breaches, group = type, colour = type)) +
      geom_line(size = 0.8) +
      theme_bw() +
      labs(x = "Time", y = "Breaches",
           title = paste("Fit from GAM",title))
    }

# %% [markdown]
# ## Preliminary GAM models (not accounting for autocorrelation)

# %% [markdown]
# ### Model 1: No interation between month and year

# %%
m1 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6), data=dtoc)
summary(m1$gam)
# Out:
# Family: gaussian
# Link function: identity
#
# Formula:
# total_atten_.4hr ~ s(mth, k = 12) + s(yr, k = 6)
#
# Parametric coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   110424       2464   44.81   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#          edf Ref.df      F  p-value
# s(mth) 3.732  3.732  18.35 1.24e-10 ***
# s(yr)  3.262  3.262 146.63  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =  0.869
#   Scale est. = 4.7983e+08  n = 80

# %% [markdown]
# Take a look at month and year components.

# %%
layout(matrix(1:2, nrow = 1))
plot(m1$gam, shade = TRUE)
# Out:
# plot without title

# %%
plot_fit(m1$gam, "model 1")
# Out:
# plot without title

# %% [markdown]
# ### Model 2: Month and Year Interaction (ignoring autocorrelation of resids)

# %%
m2 <- gamm(total_atten_.4hr ~s(mth, yr), data=dtoc)
summary(m2$gam)
# Out:
# Family: gaussian
# Link function: identity
#
# Formula:
# total_atten_.4hr ~ s(mth, yr)
#
# Parametric coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   110424       2228   49.56   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#             edf Ref.df     F p-value
# s(mth,yr) 15.71  15.71 42.48  <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =  0.892
#   Scale est. = 3.922e+08  n = 80

# %%
plot_fit(m2$gam, "model 2")
# Out:
# plot without title

# %% [markdown]
# ### Model 3: Tensor interactions(!?) (ignore errors)

# %%
m3 <- gamm(total_atten_.4hr ~ te(mth, yr, bs= c("cr", "ps")), data=dtoc)
summary(m3$gam)$r.sq
# Out:
# [1] 0.8946846

# %% [markdown]
# no real difference from splines

# %%
summary(m3$gam)$s.table
# Out:
#            edf      Ref.df   F        p-value
# te(mth,yr) 13.81033 13.81033 50.80815 9.118619e-88

# %%
plot_fit(m3$gam, "model 3")
# Out:
# plot without title

# %% [markdown]
# ### Compare basic models

# %%
anova(m1$lme, m2$lme, m3$lme)
# Out:
#        call
# m1$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
# m2$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
# m3$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
#        Model df AIC      BIC      logLik    Test   L.Ratio   p-value
# m1$lme 1     6  1856.017 1870.309 -922.0083               NA          NA
# m2$lme 2     5  1851.836 1863.746 -920.9181 1 vs 2  2.180418 0.139776460
# m3$lme 3     7  1845.349 1862.024 -915.6747 2 vs 3 10.486802 0.005282262

# %% [markdown]
# Conclusion - anova and AIC provide no strong evidence to go for interaction model over basic.  Visually it does look like we should be including an interaction between month and year!

# %% [markdown]
# ## GAM - introducing further predictors (ignoring autocorrelation)

# %%
m4 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6) + dtoc_total, data=dtoc)
m5 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6) + s(dtoc_total, k = 6), data=dtoc)

# %%
summary(m5$gam)
# Out:
# Family: gaussian
# Link function: identity
#
# Formula:
# total_atten_.4hr ~ s(mth, k = 12) + s(yr, k = 6) + s(dtoc_total,
#     k = 6)
#
# Parametric coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   110424       1947    56.7   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#                 edf Ref.df     F  p-value
# s(mth)        5.096  5.096 18.04 4.83e-13 ***
# s(yr)         1.000  1.000 56.34 4.38e-11 ***
# s(dtoc_total) 4.314  4.314 24.61 1.76e-15 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =  0.917
#   Scale est. = 2.9961e+08  n = 80

# %%
anova(m4$lme, m5$lme)
# Out:
#        call
# m4$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
# m5$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
#        Model df AIC      BIC      logLik    Test   L.Ratio  p-value
# m4$lme 1     7  1834.585 1851.259 -910.2924              NA        NA
# m5$lme 2     8  1834.276 1853.332 -909.1378 1 vs 2 2.309271 0.1286043

# %% [markdown]
# no evidence to suggest using more complex model.

# %%
plot_fit(m4$gam, "model 4 (ignoring autocorrelation)")
# Out:
# plot without title

# %%
m5 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6) 
           + dtoc_total 
           + total_admissions, 
           data=dtoc)

m6 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6) 
           + dtoc_total 
           + total_admissions
           + total_atten_t1, 
           data=dtoc)

# %%
anova(m4$lme, m5$lme, m6$lme)
# Out:
#        call
# m4$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
# m5$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
# m6$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
#        Model df AIC      BIC      logLik    Test   L.Ratio   p-value
# m4$lme 1     7  1834.585 1851.259 -910.2924               NA          NA
# m5$lme 2     8  1831.859 1850.915 -907.9293 1 vs 2  4.726307 2.97046e-02
# m6$lme 3     9  1804.909 1826.347 -893.4543 2 vs 3 28.950053 7.42688e-08

# %%
summary(m6$gam)
# Out:
# Family: gaussian
# Link function: identity
#
# Formula:
# total_atten_.4hr ~ s(mth, k = 12) + s(yr, k = 6) + dtoc_total +
#     total_admissions + total_atten_t1
#
# Parametric coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)      -1.897e+05  5.778e+04  -3.283 0.001620 **
# dtoc_total        3.914e+01  3.799e+00  10.302 1.49e-15 ***
# total_admissions -1.113e+00  2.777e-01  -4.009 0.000153 ***
# total_atten_t1    5.100e-01  8.480e-02   6.014 7.91e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#          edf Ref.df     F  p-value
# s(mth) 6.582  6.582 18.38 8.57e-16 ***
# s(yr)  1.000  1.000 59.36 1.57e-11 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =  0.933
#   Scale est. = 2.3251e+08  n = 80

# %%
plot_fit(m6$gam, "Model 6 (autocor ignored)")
# Out:
# plot without title

# %% [markdown]
# ## GAM - modelling autocorrelation in residuals

# %% [markdown]
# Starting from model 6

# %%
m6 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6) 
           + dtoc_total 
           + total_admissions
           + total_atten_t1, 
           data=dtoc)

m6_p1 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6) 
           + dtoc_total 
           + total_admissions
           + total_atten_t1, 
           data=dtoc,
           correlation = corARMA(form = ~ 1|yr, p = 1))


m6_p2 <- gamm(total_atten_.4hr ~s(mth, k = 12) + s(yr, k=6) 
           + dtoc_total 
           + total_admissions
           + total_atten_t1, 
           data=dtoc,
           correlation = corARMA(form = ~ 1|yr, p = 2))

# %%
anova(m6$lme, m6_p1$lme, m6_p2$lme)
# Out:
#           call
# m6$lme    lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
# m6_p1$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
# m6_p2$lme lme.formula(fixed = y ~ X - 1, data = strip.offset(mf), random = rand,     correlation = correlation, weights = weights, method = method,     control = control)
#           Model df AIC      BIC      logLik    Test   L.Ratio  p-value
# m6$lme    1      9 1804.909 1826.347 -893.4543              NA          NA
# m6_p1$lme 2     10 1798.893 1822.713 -889.4465 1 vs 2 8.015603 0.004637604
# m6_p2$lme 3     11 1799.736 1825.939 -888.8681 2 vs 3 1.156629 0.282165849

# %% [markdown]
# Conclusion - AR(1) has small, but sig improvement in AIC and BIC.

# %%
summary(m6_p1$gam)
# Out:
# Family: gaussian
# Link function: identity
#
# Formula:
# total_atten_.4hr ~ s(mth, k = 12) + s(yr, k = 6) + dtoc_total +
#     total_admissions + total_atten_t1
#
# Parametric coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)      -1.802e+05  5.229e+04  -3.446 0.000979 ***
# dtoc_total        3.340e+01  5.582e+00   5.983 9.11e-08 ***
# total_admissions -7.879e-01  2.978e-01  -2.646 0.010120 *
# total_atten_t1    4.034e-01  9.214e-02   4.378 4.23e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Approximate significance of smooth terms:
#          edf Ref.df     F  p-value
# s(mth) 7.013  7.014 10.87 5.34e-10 ***
# s(yr)  1.000  1.000 36.22 5.43e-08 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# R-sq.(adj) =   0.93
#   Scale est. = 2.6338e+08  n = 80

# %%
plot_fit(m6_p1$gam, "Model 6 with AR(1)")
# Out:
# plot without title

# %% [markdown]
# ### Diagnostics of Model 6 with AR(1)

# %%
par(mfrow=c(2,2))
acf(resid(m6$lme, type = "normalized"), lag.max = 48, main = "pACF of model 6")
acf(resid(m6_p1$lme, type = "normalized"), lag.max = 48, main = "pACF of model 6 with AR(1)")
pacf(resid(m6$lme, type = "normalized"), lag.max = 48, main = "pACF of model 6")
pacf(resid(m6_p1$lme, type = "normalized"), lag.max = 48, main = "pACF of model 6 with AR(1)")
# Out:
# Plot with title "pACF of model 6 with AR(1)"
